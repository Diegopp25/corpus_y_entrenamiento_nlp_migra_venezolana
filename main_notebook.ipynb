# %% [markdown]
# # Librerías

# %%
import pandas as pd

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv("Data/dataset_migracion_venezolana.csv")

# %%
df

# %%
df["Fecha"] = pd.to_datetime(
    df["Fecha"],
    errors="coerce"
)

df
