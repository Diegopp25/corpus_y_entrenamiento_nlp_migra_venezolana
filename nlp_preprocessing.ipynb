# %% [markdown]
# # Instalación de librerías para el preprocesamiento

# %%
# %pip install spacy

# %%
# %pip install scikit-learn

# %% [markdown]
# # Importe de librerías

# %%
import spacy

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# %% [markdown]
# # Preprocesamiento

# %% [markdown]
# #### Cargamos el modelo en español de spacy para preprocesamiento de texto

# %%
# !python -m spacy download es_core_news_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      ----- ---------------------------------- 1.8/12.9 MB 11.1 MB/s eta 0:00:01
#      ---------------- ----------------------- 5.2/12.9 MB 15.2 MB/s eta 0:00:01
#      ------------------------------- ------- 10.5/12.9 MB 18.4 MB/s eta 0:00:01
#      ---------------------------------------- 12.9/12.9 MB 17.5 MB/s  0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %%
# Cargar modelo en español
nlp = spacy.load('es_core_news_sm')

# %%
# Probando spacy jijijiji

texto = "Hace mucho tiempo, frente el pelotón de fusilamiento, el coronel Aureliano Buendía habría de recordar aquella remota tarde en la que su padre lo llevo a conocer el hielo"
doc = nlp(texto)

for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Aureliano Buendía PER

# %%
train_col, test_col = train_test_split(
    df['Cuerpo'],
    test_size=0.2,
    random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 train_col, test_col = train_test_split(
# ----> 2     df['column_name'],
#       3     test_size=0.2,
#       4     random_state=42
#       5 )
#
# NameError: name 'df' is not defined
